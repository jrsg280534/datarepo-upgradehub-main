# %% [markdown]
# # Ejercicios Matplotlib
#
#
# ## Datos de muestra

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(123) # SEMILLA PARA NÚMEROS ALEATORIOS
x = np.arange(0,100)
y = x*2
z = x**2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %matplotlib inline

# %% [markdown]
# ## Ejercicio 1
#
# Reproduce este dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 100)
ax.plot(x, 2*x, 'b')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_xlim([0,100])
ax.set_ylim([0,200])
yticks = [0, 50, 100, 150, 200]
ax.set_yticks(yticks)
ax.set_title('title')
ax.tick_params(direction='in', length=6, width=2, colors='b',
               grid_color='b', grid_alpha=0.5)

# %% [markdown]
# ## Ejercicio 2
#
# Reproduce el siguiente dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 100)
ax.plot(x, 2*x, 'r')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_xlim([0,100])
ax.set_ylim([0,200])
ax.tick_params(direction = 'in', rotation = 0)
ax.set_yticks(list(range(0,250,50)))
ax.set_title('title')
# inset
inset_ax = fig.add_axes([0.28, 0.520, 0.15, 0.15]) # X, Y, width, height
inset_ax.plot(x, 2*x, 'r')
# set axis range
inset_ax.set_xlim([0,100])
inset_ax.set_ylim([0,200])
# set axis tick locations
# inset_ax.set_yticks([0, 0.005, 0.01])
# inset_ax.set_xticks([-0.1,0,.1])
# Out:
# (0.0, 200.0)

# %% [markdown]
# ## Ejercicio 3
#
# Reproduce el siguiente dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
fig, ax = plt.subplots()

ax.plot(x, x, x, x**2)
fig.tight_layout()

# inset
inset_ax = fig.add_axes([0.2, 0.55, 0.35, 0.35]) # X, Y, width, height

inset_ax.plot(x, x, x, x)
inset_ax.set_title('zoom')

# set axis range
inset_ax.set_xlim(20, 22)
inset_ax.set_ylim(20, 50)

# set axis tick locations
inset_ax.set_yticks([0,50,150,200])
inset_ax.set_xticks([-0.1,0,.1])
# Out:
# [<matplotlib.axis.XTick at 0x7fbbf1ee1f90>,
#  <matplotlib.axis.XTick at 0x7fbbf1ee1f50>,
#  <matplotlib.axis.XTick at 0x7fbbf1ee1990>]

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 100, 1000)
ax.plot(x, x**2, 'b')
ax.set_xlabel('X')
ax.set_ylabel('Z')
ax.set_xlim([0,100])
ax.set_ylim([0,200])
ax.tick_params(direction = 'in', rotation = 0)
ax.set_yticks(list(range(0,12000,2000)))
ax.set_title('title')
# inset
inset_ax = fig.add_axes([0.28, 0.520, 0.3, 0.3]) # X, Y, width, height
# set axis range
inset_ax.set_xlim([0, 50])
inset_ax.set_ylim([30, 50])
inset_ax.plot(x, x**2, 'b')
inset_ax.set_yticks(list(range(30,55,5)))
inset_ax.set_xticks(list(range(20,23,1)));

# %% [markdown]
# ## Ejercicio 4
#
# Reproduce el siguiente dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
fig, axes = plt.subplots(1, 2, figsize=(6,4))
fig.tight_layout()
x = np.linspace(0,100, 1000)
# default grid appearance
axes[0].plot(x, 2*x, lw=2, linestyle='dashed', color = 'b')
axes[0].set_xlim([0,100])
axes[0].set_ylim([0,200])
axes[0].set_yticks(list(range(0,250,50)))
axes[0].tick_params(direction = 'in', rotation = 0)
# custom grid appearance
axes[1].plot(x, x**2, lw=4, color = 'r')
axes[1].set_xlim([0,100])
axes[1].set_ylim([0,10000])
axes[1].tick_params(direction = 'in', rotation = 0)

# %% [markdown]
# ## Ejercicio 5
#
# Reproduce el siguiente dibujo:
#
# ![image.png](data:image/png;base64,...)

# %%
fig, axes = plt.subplots(1,2, figsize=(13,3))
fig.tight_layout()
x = np.linspace(0,100, 1000)
# default grid appearance
axes[0].plot(x, 2*x, lw=2, linestyle='dashed', color = 'b')
axes[0].set_xlim([0,100])
axes[0].set_ylim([0,200])
axes[0].set_yticks(list(range(0,250,50)))
axes[0].tick_params(direction = 'in', rotation = 0)
# custom grid appearance
axes[1].plot(x, x**2, lw=4, color = 'r')
axes[1].set_xlim([0,100])
axes[1].set_ylim([0,10000])
axes[1].tick_params(direction = 'in', rotation = 0)

# %%
fig, axes = plt.subplots(1, 2, figsize=(20,4))

fig.tight_layout()

x = np.linspace(0,1000, 1000)

# default grid appearance
axes[0].plot(x, 2*x, lw=3, linestyle='-', color = 'b')
axes[0].set_xlim([0,100])
axes[0].set_ylim([0,100])
axes[0].set_yticks(list(range(0,250,50)))
axes[0].tick_params(direction = 'in', rotation = 0)

# custom grid appearance
axes[1].plot(x, x**2, lw=4,linestyle='--', color = 'r')
axes[1].set_xlim([0,100])
axes[1].set_ylim([0,10000])
axes[1].tick_params(direction = 'in', rotation = 0)

# %% [markdown]
# ## Ejercicio 6
#
# Reproduce el siguiente dibujo a partir del código
#
# ```python
# # Ejes
# ax = plt.axes(projection='3d')
# # Línea
# zline = np.linspace(0, 15, 1000)
# xline = np.sin(zline)
# yline = np.cos(zline)
# # Nube de puntos
# zdata = 15 * np.random.random(100)
# xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
# ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
# ```
#
# ![image.png](data:image/png;base64,...)

# %%
# Ejes
ax = plt.axes(projection='3d')
# Línea
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
# Nube de puntos
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
#dibujar ahora la nube de puntos
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens')
#añadirle una línea
ax.plot3D(xline, yline, zline, 'gray')
ax.view_init(20, 25)
