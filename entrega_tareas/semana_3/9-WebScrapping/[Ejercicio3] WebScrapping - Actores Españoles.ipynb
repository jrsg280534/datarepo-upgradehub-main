# %% [markdown]
# # Descripción
# Extraiga de IMDB los actores nacidos en España.
#
# Pasos:
# * 1 - Localizamos la web de IMDB: https://www.imdb.com/
# * 2 - Vamos a la seccion de búsqueda: https://www.imdb.com/find?s=nm&q=
# * 3 - Jugamos con los parámetros para localizar la URL: https://www.imdb.com/search/name/?birth_place=Spain&adult=include&count=100&start=1&ref_=rlm
# En los parámetros vemos que el nacimiento lo hemos puesto en "spain" y que el número de registro está situado en 100.
# * 4 - Imprima la lista de nombres en una tabla junto con la pequeña descripción (Bio) y su foto
# * 5 - Recuerde que los datos se encuentra en la parte HTML "div" y la clase correspondiente es "lister-item mode-detail"

# %% [markdown]
# # Extra
# Para imprimir la foto, usamos el siguiente código:
# ```
#
# from IPython.core.display import HTML
#
# # Convertir una URL en una iamgen
# def path_to_image_html(path):
#     return '<img src="'+ path + '" width="60" >'
#
# pd.set_option('display.max_colwidth', -1)
#
# # informacion_actores: Dataframe con la información
# # Imagen: Columna con la URL de las imánes de los actores y actrices
# HTML(informacion_actores.to_html(escape=False ,formatters=dict(Imagen=path_to_image_html)))
# ```
