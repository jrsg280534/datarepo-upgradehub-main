# %% [markdown]
# ¿A qué se corresponde el número binario 01011001 en ASCII?

# %%
# !pip install beautifulsoup4
# !pip install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
enlace = 'https://proyectoa.com/tabla-de-correspondencias-ascii-y-iso-8859-1/'
texto_web = requests.get(enlace).text
print(texto_web)

# %%
from bs4 import BeautifulSoup
sopa = BeautifulSoup(texto_web, 'lxml')
print(sopa)

# %%
tablas = sopa.find_all('table')
print(tablas)

# %%
tablas = sopa.find_all('table')

# %%
import pandas as pd
dataframe_informacion = pd.read_html(str(tablas))
print(dataframe_informacion)
# Out:
# [                      0    1    2     3
# 0                Nombre  Dec  Hex  Car.
# 1                  Nulo    0    0   NUL
# 2    Inicio de cabecera    1    1   SOH
# 3       Inicio de texto    2    2   STX
# 4          Fin de texto    3    3   ETX
# ..                  ...  ...  ...   ...
# 125                 NaN  123   7B     {
# 126                 NaN  124   7C     |
# 127                 NaN  125   7D     }
# 128                 NaN  126   7E     ~
# 129                 NaN  127   7F   DEL
#
# [130 rows x 4 columns],                                                    0  \
# 0  1234567891011121314151617181920212223242526272...
#
#                                                    1
# 0  Oct Dec Hex Carac Descripción-----------------...  ]

# %%
url = "https://proyectoa.com/tabla-de-correspondencias-ascii-y-iso-8859-1/"
tabla_ASCII = pd.read_html(url)[0]
print (tabla_ASCII)
# Out:
#                       0    1    2     3
# 0                Nombre  Dec  Hex  Car.
# 1                  Nulo    0    0   NUL
# 2    Inicio de cabecera    1    1   SOH
# 3       Inicio de texto    2    2   STX
# 4          Fin de texto    3    3   ETX
# ..                  ...  ...  ...   ...
# 125                 NaN  123   7B     {
# 126                 NaN  124   7C     |
# 127                 NaN  125   7D     }
# 128                 NaN  126   7E     ~
# 129                 NaN  127   7F   DEL
#
# [130 rows x 4 columns]

# %%
valor = int ('01011001',2)

# %%
tabla_ASCII[3].iloc[valor + 2]
# Out:
# 'Y'
